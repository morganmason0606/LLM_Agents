# %%
import tabula
sources = {
    'fed': "./data/2024-dfast-results-20240626.pdf",
    'usb' :"./data/U-S-Bancorp-CCAR-2024-Disclosure_Final.pdf"
} 

# Read pdf into list of DataFrame
dfs = tabula.read_pdf(sources['usb'], pages='all')
# Out:
# Failed to import jpype dependencies. Fallback to subprocess.
# No module named 'jpype'

# %%
dfs[0]
# Out:
#    Capital ratios, actual 2023:Q4 and projected 2024:Q1-2026:Q1  \
# 0                                         Supervisory
# 1             Regulatory Actual Severely Adverse  (1)
# 2     Regulatory Ratio Minimum 2023:Q4 Ending Minimum
# 3   Common equity tier 1 capital ratio 4.5% 9.9% 8...
# 4          Tier 1 capital ratio 6.0% 11.5% 10.4% 9.9%
# 5          Total capital ratio 8.0% 13.7% 12.4% 11.9%
# 6           Tier 1 leverage ratio 4.0% 8.1% 7.9% 7.3%
# 7    Supplementary leverage ratio 3.0% 6.6% 6.2% 5.7%
# 8   (1) The capital ratios are calculated using th...
# 9   involve an economic outcome that is more adver...
# 10                Net income and risk-weighted assets
# 11  Projected losses, revenue, and net income befo...
# 12                                                NaN
# 13                                            2026:Q1
# 14  Supervisory Severely Adverse Scenario Supervis...
# 15                                         Percent of
# 16             Billions of dollars average assets (1)
# 17  Pre-provision net revenue 14.0 2.2% Other comp...
# 18                   equals Other effects on capital:
# 19                 AOCI included in capital (billions
# 20                      Net interest income 32.5 5.1%
# 21                                        of dollars)
# 22                       Noninterest income 21.0 3.3%
# 23                                               less
# 24                  Noninterest expense (2) 39.5 6.2%
# 25                              Other revenue (3) 0.0
# 26         less Supervisory Severely Adverse Scenario
# 27          Provisions for loan and lease losses 18.5
# 28                        Credit losses on investment
# 29    securities (AFS/HTM) (4) 0.0Billions of dollars
# 30  Trading and counterparty losses (5) 0.0 Risk-w...
#
#               Unnamed: 0                              Unnamed: 1
# 0                Minimum                                     NaN
# 1                 versus                                     NaN
# 2                2023:Q4                                     NaN
# 3                  -1.6%                                     NaN
# 4                  -1.6%                                     NaN
# 5                  -1.8%                                     NaN
# 6                  -0.8%                                     NaN
# 7                  -0.9%                                     NaN
# 8                    NaN                                     NaN
# 9                    NaN                                     NaN
# 10                   NaN                                     NaN
# 11                   NaN                                     NaN
# 12            Memo items                                     NaN
# 13                   NaN                                     NaN
# 14                   NaN                                     NaN
# 15                   NaN                              Percent of
# 16                   NaN  Billions of dollars average assets (1)
# 17                   NaN                                     0.0
# 18                   NaN                  Actual 2023:Q4 2026:Q1
# 19                   NaN                                     NaN
# 20                   NaN                             (0.0) (0.0)
# 21                   NaN                                     NaN
# 22                   NaN                                     NaN
# 23                   NaN                                     NaN
# 24                   NaN                                     NaN
# 25  Risk-Weighted Assets                                     NaN
# 26                   NaN                                     NaN
# 27                   NaN                        Actual Projected
# 28                   NaN                                     NaN
# 29                   NaN                  Actual 2023:Q4 2026:Q1
# 30                   NaN                             453.4 446.8
