# %%
# load relevant environment variables
from dotenv import load_dotenv
import os

# %%
#load env vars
load_dotenv()
API_KEY = os.getenv("OPENAI_API_KEY")

# %%
#chatgpt model I wish to use
gpt_model_name = "gpt-3.5-turbo-0125"

# %%
from langchain_openai import ChatOpenAI

# %%
#create model
llm = ChatOpenAI(
    api_key=API_KEY, #so long as your env has a OPENAI_API_KEY variable, this does not need to be done explicitly 
    model=gpt_model_name,
    max_retries=2,
)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
messages = [
    (
        "system",
        "You are a helpful assistant that translates English to French. Translate the user sentence.",
    ),
    ("human", "I love programming."),
]
ai_msg = llm.invoke(messages)
ai_msg
# Out:
# AIMessage(content="J'adore programmer.", response_metadata={'token_usage': {'completion_tokens': 6, 'prompt_tokens': 31, 'total_tokens': 37}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-97d0be03-7496-46eb-aa99-8c2e477726be-0', usage_metadata={'input_tokens': 31, 'output_tokens': 6, 'total_tokens': 37})
