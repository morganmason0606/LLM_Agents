# %%
sources = {
    'fed': "./data/2024-dfast-results-20240626.pdf",
    'usb' :"./data/U-S-Bancorp-CCAR-2024-Disclosure_Final.pdf"
}

# %% [markdown]
# ## pytesseract

# %%
import PIL 
from PIL import Image
import pytesseract

# %% [markdown]
# # PyMuPDF

# %%
import pymupdf

# %%
doc = pymupdf.open(sources['fed'], filetype='pdf')

# %%
tables=[]
for p in doc:
    tables.extend(p.find_tables(
        #strategy='text',
    ))

# %%
print(len(tables), type(tables[0]))
print(tables[0])
# Out:
# 59 <class 'pymupdf.table.Table'>
# ...

# %%
pymupdf.table.Table.__dict__
# Out:
# mappingproxy({'__module__': 'pymupdf.table',
#               '__init__': <function pymupdf.table.Table.__init__(self, page, cells)>,
#               'bbox': <property at 0x1bd4866f790>,
#               'rows': <property at 0x1bd4866f7e0>,
#               'row_count': <property at 0x1bd4866f830>,
#               'col_count': <property at 0x1bd4866f880>,
#               'extract': <function pymupdf.table.Table.extract(self, **kwargs) -> list>,
#               'to_markdown': <function pymupdf.table.Table.to_markdown(self, clean=True)>,
#               'to_pandas': <function pymupdf.table.Table.to_pandas(self, **kwargs)>,
#               '_get_header': <function pymupdf.table.Table._get_header(self, y_tolerance=3)>,
#               '__dict__': <attribute '__dict__' of 'Table' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Table' objects>,
#               '__doc__': None})

# %%
i = 0

# %%
i+=1
pds = tables[i].to_pandas()
pds
# Out:
#    Median=–1.4  Col1  Col2  Col3  Col4  Col5  Col6  Col7  Col8  Col9 Col10  \
# 0         None  None  None  None  None  None  None  None  None  None  None
# 1         None  None  None  None  None  None  None  None  None  None  None
# 2         None  None  None  None  None  None  None  None  None  None  None
# 3         None  None  None        None  None  None  None  None  None  None
# 4         None  None  None  None  None  None  None  None  None  None  None
# 5         None        None  None  None  None  None  None  None  None  None
# 6         None  None  None  None  None  None  None  None  None  None  None
# 7         None  None  None  None        None  None  None  None  None  None
# 8         None  None  None  None  None  None  None  None  None  None  None
# 9         None  None        None  None  None  None  None  None  None  None
# 10        None  None  None  None  None  None  None  None  None  None  None
# ...

# %% [markdown]
# pymupdf still seems to have trouble with pdfs
