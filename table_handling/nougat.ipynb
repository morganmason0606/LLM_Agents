# %% [markdown]
# https://github.com/facebookresearch/nougat

# %%
table_handling/data/2024

# %%
# %pip install nougat-ocr
# Out:
# ...
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ---------------------------------------- 57.6/57.6 kB ? eta 0:00:00
# ...
#    ---------------------------------------- 0.0/82.5 kB ? eta -:--:--
#    ------------------------ --------------- 51.2/82.5 kB 871.5 kB/s eta 0:00:01
#    ---------------------------------------- 82.5/82.5 kB 1.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/431.5 kB ? eta -:--:--
#    ---------- ----------------------------- 112.6/431.5 kB 3.3 MB/s eta 0:00:01
#    ------------ --------------------------- 133.1/431.5 kB 2.6 MB/s eta 0:00:01
#    ----------------- ---------------------- 184.3/431.5 kB 1.4 MB/s eta 0:00:01
#    -------------------------- ------------- 286.7/431.5 kB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  430.1/431.5 kB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 431.5/431.5 kB 1.8 MB/s eta 0:00:00
# ...
